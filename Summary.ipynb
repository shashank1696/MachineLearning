# %%
import sklearn.ensemble as ensemble
import pandas as pd
import numpy as np
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
stack = pd.read_csv("H:\python\stackoverflow.csv", encoding = 'latin1')

# %%
stack.head()
# Out:
#    RespondentID         Country    Salary  YearsCodedJob  OpenSource  Hobby  \
# 0             3  United Kingdom  113750.0             20           1      1
# 1            15  United Kingdom  100000.0             20           0      1
# 2            18   United States  130000.0             20           1      1
# 3            19   United States   82500.0              3           0      1
# 4            26   United States  175000.0             16           0      1
#
#    CompanySizeNumber      Remote  CareerSatisfaction  Datascientist  ...   \
# 0            10000.0  Not remote                   8              0  ...
# 1             5000.0      Remote                   8              0  ...
# 2             1000.0      Remote                   9              0  ...
# 3            10000.0  Not remote                   5              0  ...
# 4            10000.0  Not remote                   7              0  ...
#
# ...

# %%
stack.columns
# Out:
# Index(['RespondentID', 'Country', 'Salary', 'YearsCodedJob', 'OpenSource',
#        'Hobby', 'CompanySizeNumber', 'Remote', 'CareerSatisfaction',
#        'Datascientist', 'Database administrator',
#        'Desktop applications developer',
#        'Developer with stats/math background', 'DevOps', 'Embedded developer',
#        'Graphic designer', 'Graphics programming',
#        'Machine learning specialist', 'Mobile developer',
#        'Quality assurance engineer', 'Systems administrator', 'Web developer',
#        '    '],
#       dtype='object')

# %%
a = stack.query("Remote == 'Not remote' ").agg({'Remote':['mean','count']})#avg,sum and count for flight delayed on friday
a
# Out:
#        Remote
# count    6273

# %%
stack.query("Country == 'United Kingdom'").agg({'Country':['mean','count']})
# Out:
#        Country
# count     1270

# %%
stack.query("Country == 'United Kingdom' ").groupby("Database administrator").agg({'Database administrator':['mean','count']})
# Out:
#                        Database administrator
#                                          mean count
# Database administrator
# 0                                           0  1074
# 1                                           1   196
